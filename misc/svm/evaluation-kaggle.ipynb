# %% [markdown]
# ## Next Step:
#
# Conduct with Belmond-Shiba

# %%
import pickle
# load
with open('model-kaggle.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
talent_list = [
    {
        "name": "アンジュ・カトリーナ",
        "path": "/content/drive/MyDrive/DataScience/chat-ange.npy",
        "color": "#C83C35",
    },
    {
        "name": "リゼ・ヘルエスタ",
        "path": "/content/drive/MyDrive/DataScience/chat-lize.npy",
        "color": "#42FFFF",
    },
    {
        "name": "戌亥とこ",
        "path": "/content/drive/MyDrive/DataScience/chat-toko.npy",
        "color": "#92F3A4",
    }
]

# %%
import librosa
audio_filepath = "../data_collection/test-voice/sanbaka-sightseeing.mp4"

# Parameters for mel-spectrogram
sample_rate = 22050  # Standard sample rate for Librosa. Basically equal to sample rate of the audio.
n_mels = 128         # Number of mel bands
n_fft = 2048         # Length of the FFT window -> ブログのやつでは173(分解能を11.5ms にするため！)
hop_length = 256     # Number of samples between successive frames
win_length = n_fft     # window length
segment_duration = 2  # seconds

y, sr = librosa.load(audio_filepath, sr = sample_rate)
# Out:
# /var/folders/n9/f02ch2416_7cp5wybnwwhh7r0000gn/T/ipykernel_7373/3694596002.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_filepath, sr = sample_rate)
# /opt/miniconda3/envs/general/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
# Kaggle code (https://www.kaggle.com/code/anmour/svm-using-mfcc-features)

import numpy as np
import pandas as pd

import os
import librosa

import scipy
from scipy.stats import skew
from tqdm import tqdm, tqdm_pandas

tqdm.pandas()

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.svm import SVC

# Generate mfcc features with mean and standard deviation
def get_mfcc(segment, SAMPLE_RATE):
    data = segment
    # try:

    ft1 = librosa.feature.mfcc(y = data, sr = SAMPLE_RATE, n_mfcc=30)
    ft2 = librosa.feature.zero_crossing_rate(y = data)[0]
    ft3 = librosa.feature.spectral_rolloff(y = data, sr = SAMPLE_RATE)[0]
    ft4 = librosa.feature.spectral_centroid(y = data, sr = SAMPLE_RATE)[0]
    ft5 = librosa.feature.spectral_contrast(y = data, sr = SAMPLE_RATE)[0]
    ft6 = librosa.feature.spectral_bandwidth(y = data, sr = SAMPLE_RATE)[0]
    ft1_trunc = np.hstack((np.mean(ft1, axis=1), np.std(ft1, axis=1), skew(ft1, axis = 1), np.max(ft1, axis = 1), np.median(ft1, axis = 1), np.min(ft1, axis = 1)))
    ft2_trunc = np.hstack((np.mean(ft2), np.std(ft2), skew(ft2), np.max(ft2), np.median(ft2), np.min(ft2)))
    ft3_trunc = np.hstack((np.mean(ft3), np.std(ft3), skew(ft3), np.max(ft3), np.median(ft3), np.min(ft3)))
    ft4_trunc = np.hstack((np.mean(ft4), np.std(ft4), skew(ft4), np.max(ft4), np.median(ft4), np.min(ft4)))
    ft5_trunc = np.hstack((np.mean(ft5), np.std(ft5), skew(ft5), np.max(ft5), np.median(ft5), np.min(ft5)))
    ft6_trunc = np.hstack((np.mean(ft6), np.std(ft6), skew(ft6), np.max(ft6), np.median(ft6), np.max(ft6)))
    return pd.Series(np.hstack((ft1_trunc, ft2_trunc, ft3_trunc, ft4_trunc, ft5_trunc, ft6_trunc)))
    
    # except:
    #     print('bad file')
    #     return pd.Series([0]*210)

# %%
import pandas as pd
import numpy as np
import librosa

diarization = pd.read_csv("../pyannote/result-sightseeing.csv")

labels = [d["name"] for d in talent_list]
colors = [d["color"] for d in talent_list]

# Example entries
srt_elements = [
    # {'start': 1.0, 'end': 4.0, 'text': 'This is red text', 'color': '#FF0000'},
    # {'start': 5.0, 'end': 7.0, 'text': 'This is green text', 'color': '#00FF00'},
    # {'start': 6.5, 'end': 10.0, 'text': 'This is blue text overlapping', 'color': '#0000FF'},
]

for index, row in diarization.iterrows():
    print(f"{row["start"]} - {row["end"]}: {row["speaker"]} said, ''{row["text"]}''")
    start = max(int(sr * row["start"]), 0)
    end = min(int(sr * row["end"]), len(y))
    turn = y[start:end]

    turn_len = len(turn)
    # 0-2, 1-3, 2-4,,,
    num_segments = int( turn_len / sr ) #  - segment_duration + 1
    mfccs = []
    for segment_index in range(num_segments):
        segment = y[segment_index * sr : (segment_index + 1 ) * sr ]
        # (segment_index + segment_duration) * sr ]

        segment = np.concatenate((segment, segment), axis = 0)

        # mfcc = np.mean(librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=13)[1:], axis=1)
        mfcc = get_mfcc(segment, 22050)
        if np.isnan(mfcc).any():
            # if mfcc array contain nan value, skip
            continue
        
        mfccs.append(mfcc)

    if len(mfccs) == 0:
        print("Turn's duration is under 2 sec. Unable to evaluate")
        continue

    # change to PCA
    # Apply scaling for PCA
    scaler = StandardScaler()
    mfccs_scaled = scaler.fit_transform(mfccs)
    # Apply PCA for dimension reduction
    import pickle
    pca = pickle.load(open("pca.pkl",'rb'))
    mfccs_pca = pca.transform(mfccs_scaled)
    
    predictions = model.predict(mfccs_pca)
    print(predictions)

    values, counts = np.unique(predictions, return_counts=True)
    print(values)
    print(counts)

    print(f"Most Dominant: {values[np.argmax(counts)]}")

    color = colors[np.argmax(counts)]

    srt_elements.append({
        'start': row["start"],
        'end': row["end"],
        'text': row["text"],
        'color': color
    })
# Out:
# 0.03096875 - 5.53221875: SPEAKER_01 said, ''音量調整したけど視聴者さん側にも念のため聞いてもらおうかにしましょう''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 5.53221875 - 8.974718750000001: SPEAKER_00 said, ''了解誰''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 8.974718750000001 - 18.47534375: SPEAKER_01 said, ''あ、じゃあお待たせ。わかった。23人所属、公式美少子連輪知らばの安寿カトリーナだ!よろしくお願いしまーす。''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 6]
# Most Dominant: 戌亥とこ
# 9.97034375 - 10.493468750000002: SPEAKER_02 said, ''あ、だっ''
# Turn's duration is under 2 sec. Unable to evaluate
# 10.45971875 - 10.476593750000005: SPEAKER_00 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 18.47534375 - 20.70284375: SPEAKER_00 said, ''こんな感じなんだっけコラボの時''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 22.99784375 - 31.80659375: SPEAKER_02 said, ''いつもこうだよ裏では元気ないみたいなそんなことないどうぞどうぞ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 25.27596875 - 28.26284375: SPEAKER_00 said, ''裏では元気いないみたいな''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 29.52846875 - 35.53596875: SPEAKER_00 said, ''お腹痛めてたなって思って薬飲んで''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 35.53596875 - 39.53534375: SPEAKER_01 said, ''鳥雑炊食べすぎてもう無事ならいいんだ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 40.37909375 - 40.88534375: SPEAKER_01 said, ''どうぞ''
# Turn's duration is under 2 sec. Unable to evaluate
# 44.37846875 - 49.00221875: SPEAKER_00 said, ''毎度ヘルストの北大二公女リゼ・ヘルストです。よろしくお願いします。''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 44.68221875 - 44.81721875: SPEAKER_02 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 45.52596875 - 46.70721875: SPEAKER_02 said, '' Ócorén''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 47.97284375 - 52.49534375: SPEAKER_01 said, ''よろしくお願いしますあれ?ってことはこっちは?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 54.38534375 - 54.53721875: SPEAKER_01 said, ''チャンネル登録をお願いいたします。''
# Turn's duration is under 2 sec. Unable to evaluate
# 54.53721875 - 61.523468750000006: SPEAKER_00 said, ''誰か映ってんな画角がドアとか映してしまった''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 60.696593750000005 - 61.16909375: SPEAKER_01 said, ''えっと''
# Turn's duration is under 2 sec. Unable to evaluate
# 64.76346875 - 65.03346875: SPEAKER_01 said, ''おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえちゃん、おねえ''
# Turn's duration is under 2 sec. Unable to evaluate
# 66.28221875 - 66.94034375000001: SPEAKER_01 said, ''なかえて fresh''
# Turn's duration is under 2 sec. Unable to evaluate
# 67.80096875000001 - 68.98221875: SPEAKER_01 said, ''よし..''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 68.98221875 - 73.47096875: SPEAKER_00 said, ''2日パッと出ないって話してるよあのー、挨拶ない''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 73.47096875 - 86.97096875000001: SPEAKER_01 said, ''そう、だからこう…いや、立派な情勢のためにだって工場は自分のやつ言うてはったからwww毎度だけ言ってて工場は自分の言うてはったからそうさって言うてはないし毎度消すだけになってるwww''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [2 3 8]
# Most Dominant: 戌亥とこ
# 76.67721875000001 - 77.33534375: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 86.97096875000001 - 97.50096875: SPEAKER_00 said, ''そこで住まれただけ公式つよつよケルベロスからだけやってもらえたらちょうど合わせた時に公式つよつよケルベロスいないとこです''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 6]
# Most Dominant: 戌亥とこ
# 95.29034375 - 95.47596875: SPEAKER_02 said, ''いっ''
# Turn's duration is under 2 sec. Unable to evaluate
# 97.50096875 - 108.53721875: SPEAKER_02 said, ''え?あれ?あ、カナの方のやったんだなんか、実物より可愛かったんだけどマイクないとそうなるの?''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 7]
# Most Dominant: 戌亥とこ
# 106.02284375 - 107.15346875: SPEAKER_00 said, ''前がないとそうなるの?''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 106.96784375 - 107.27159375: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 108.53721875 - 115.52346875: SPEAKER_00 said, ''セバスよりの朝の配信でたまにサービスしてる時の男じゃん''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 115.52346875 - 118.03784375: SPEAKER_02 said, ''nan''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 120.92346875 - 123.50534375: SPEAKER_01 said, ''ここの肝ダメージはいたもんね、一人用のやつは''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 121.68284375 - 122.49284375: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 123.23534375 - 130.79534375: SPEAKER_00 said, ''いたいた!ちっちゃいホラーハウスいたやつねあれ?これじゃない?挑戦あ、ほんまガラガラ1つに合わない''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 127.97721875000002 - 134.17034375: SPEAKER_01 said, ''あ、ほんまにガラガラ1枚だ!私3枚貰ったからキスピに1枚ずつ回そうや''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 134.49096875 - 138.49034375000002: SPEAKER_00 said, ''あ、なるほど。そういう意図で3だったのかな?どうだろう?ほい!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 136.81971875000002 - 137.37659375: SPEAKER_01 said, '' Kom''
# Turn's duration is under 2 sec. Unable to evaluate
# 140.05971875 - 143.18159375000002: SPEAKER_00 said, ''え、じゃあ、行ってみていいか?どうぞどうぞ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 144.02534375000002 - 147.85596875000002: SPEAKER_00 said, ''1等金2等青ここなんか奥にね書いてあるわ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 149.18909375 - 149.20596875: SPEAKER_00 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 149.20596875 - 157.72784375: SPEAKER_01 said, ''あ、なんか前あった気がするあ、チュールとかそういえばやってたねあったあったあった猫がね、めっちゃ喜ぶんだよねこういうのでもさ、なんか''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 152.39534375000002 - 153.72846875000002: SPEAKER_00 said, ''そういえばやってたね''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 156.19221875000002 - 156.22596875000002: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 158.41971875000002 - 160.59659375: SPEAKER_01 said, ''3等ぐらいのやつ欲しいときになります''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 160.59659375 - 164.81534375: SPEAKER_00 said, ''3等… いや確かにウチは欲しいな行くぞ!2位いいな''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 166.50284375 - 180.52596875: SPEAKER_00 said, ''左下のレバーを下げて回転スタートこれか、いくよほい!回ってる回ってる!レバーを上げて回転ストップいくよ、上げるよほい!え?''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' 'アンジュ・カトリーナ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [3 3 8]
# Most Dominant: 戌亥とこ
# 168.07221875000002 - 168.47721875000002: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 174.33284375000002 - 175.17659375000002: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 180.52596875 - 184.98096875: SPEAKER_02 said, ''え?嘘じゃん!え?嘘?女中!女中だ!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 184.98096875 - 189.18284375: SPEAKER_01 said, ''あ、おめでとうって書いてあるすげーねーほんとおめでとうって書いてある''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 187.57971875 - 189.03096875: SPEAKER_00 said, ''ねぇ、ほんとおめでとうって書いてある''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 190.22909375 - 222.24096875: SPEAKER_01 said, ''やるねー!やったー!そこまで入ってあかんと思ってそこが多分いいやと思うわ近くで見たいじゃあほんまやるかこれどうやるの?いやって言われたこれいいのか抽選するかい?うちはもうかわいいかわいくない?こうかレバーで回るえ?え?え?なんでなんでなんでなんで?え?え?え?なんで?なんで?攻略者?なんでなんでなんで?ジュさんの辛いの映った?なんで殺してるの?え?え?''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' 'アンジュ・カトリーナ'
#  'アンジュ・カトリーナ' 'アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ'
#  'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [ 7  9 16]
# Most Dominant: 戌亥とこ
# 195.03846875 - 197.43471875: SPEAKER_00 said, ''パパにとこ多分、いや、近くで見たい''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 203.52659375 - 205.46721875: SPEAKER_02 said, ''注線するからいつも何が出るかな''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 222.24096875 - 222.52784375: SPEAKER_02 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 223.11846875 - 227.10096875: SPEAKER_02 said, ''でも、普通にくれた。 燃やしたらくれた。''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 228.65346875 - 235.03221875000003: SPEAKER_00 said, ''うちは当たったんだよねかわいい激圧演出だったんかなそういうこと激圧''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 233.59784375 - 243.67221875: SPEAKER_01 said, ''そういうこと激圧かっこ物理みたいなことこっちかこっちみたいなこっちかこっちあ、出てないようなペラペラキャンディ可愛いな可愛いよな全部可愛い正直参加外れ''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 6]
# Most Dominant: 戌亥とこ
# 233.78346875000005 - 234.18846875000003: SPEAKER_02 said, ''そういうこと!''
# Turn's duration is under 2 sec. Unable to evaluate
# 236.02784375 - 236.97284375: SPEAKER_02 said, ''こっちから''
# Turn's duration is under 2 sec. Unable to evaluate
# 244.98846875 - 251.11409375: SPEAKER_01 said, ''がんばれがんばれおじさん、おじさんさあ何が出るかな?左のレバー''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 246.76034375 - 246.91221875: SPEAKER_02 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 249.93284375 - 249.94971875: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 251.97471875 - 252.64971875: SPEAKER_01 said, ''それそれ''
# Turn's duration is under 2 sec. Unable to evaluate
# 252.05909375 - 252.27846875000003: SPEAKER_02 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 253.96596875000003 - 257.64471875000004: SPEAKER_01 said, ''德府''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 254.96159375 - 255.97409375: SPEAKER_00 said, ''持ってる持ってる''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 258.53909375 - 263.97284375000004: SPEAKER_01 said, ''あ!お揃いだ!お揃いや!そうなるとうちはいいなぁ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 261.52596875 - 261.67784375: SPEAKER_02 said, ''お疲れ様でした。''
# Turn's duration is under 2 sec. Unable to evaluate
# 263.02784375000005 - 271.97159375: SPEAKER_02 said, ''でもそれも確かにそううちはもういいなそうなってくるとそうなってくるとちょっと私もうちは欲しい''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 266.53784375000004 - 268.47846875: SPEAKER_01 said, ''止まってくるぞ''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 268.47846875 - 270.92534375: SPEAKER_00 said, ''私も家を欲しい''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 275.14409375 - 275.24534375: SPEAKER_02 said, ''ん?''
# Turn's duration is under 2 sec. Unable to evaluate
# 279.22784375000003 - 285.52221875000004: SPEAKER_02 said, ''もうタイムで愛石しに行く''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 279.36284375 - 282.90659375: SPEAKER_00 said, ''ノータイムで愛石しに行く''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 279.68346875000003 - 279.97034375000004: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 291.09096875 - 296.64284375: SPEAKER_00 said, ''何を考えているんだろうなリンさんこの瞬間にあ動いた!あ!あ投げてきた!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 291.17534375 - 292.64346875: SPEAKER_02 said, ''何を考えているのか?''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 295.73159375 - 299.96721875000003: SPEAKER_02 said, ''あ、投げてきた。丼に投げてくんが危なくない?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 297.72284375000004 - 298.31346875: SPEAKER_00 said, ''おめでとうございます''
# Turn's duration is under 2 sec. Unable to evaluate
# 299.96721875000003 - 302.85284375000003: SPEAKER_00 said, ''リンさん私も私も''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 303.84846875 - 304.43909375000004: SPEAKER_01 said, ''だめだよ''
# Turn's duration is under 2 sec. Unable to evaluate
# 305.04659375 - 305.83971875000003: SPEAKER_00 said, ''私も''
# Turn's duration is under 2 sec. Unable to evaluate
# 308.38784375 - 310.96971875: SPEAKER_01 said, ''いやでもどういう絵面?''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 310.53096875 - 319.40721875: SPEAKER_02 said, ''あ、これ、これ、いや、そのあげ方は、ハトにあげる感じなんよwwwwwwパパパパッ腹巻いてはるwwwwwwいいなぁwwwwwwww''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 312.97784375000003 - 313.02846875: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 316.03221875 - 316.53846875: SPEAKER_01 said, ''まいては''
# Turn's duration is under 2 sec. Unable to evaluate
# 322.66409375 - 329.05971875: SPEAKER_01 said, ''ね、すごいね。なんたくどうやってるのか、本当に検討つかん。うんうんうん。あれ?あれ?オムライスさんがなくなってる!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 329.05971875 - 340.85534375000003: SPEAKER_00 said, ''そんな地図にあったはず!オムレスカーが!オムレスカー!そんなことない!あったはず地図にはあれ?移設してるとかじゃなくて何?横も知らないのある''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 7]
# Most Dominant: 戌亥とこ
# 338.13846875 - 344.46659375: SPEAKER_01 said, ''あ、でもさっきオムライス持ってたやん持ってた!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 345.58034375 - 349.52909375: SPEAKER_00 said, ''イモじゃねえ、切り抜くからちょっとオムライスカーオムライスカーどこ?www''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 345.61409375 - 346.47471875: SPEAKER_01 said, ''今じゃね?''
# Turn's duration is under 2 sec. Unable to evaluate
# 346.47471875 - 348.04409375: SPEAKER_02 said, ''だから、ちょっと、いろいろできるんじゃないか''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 351.09846875 - 353.03909375: SPEAKER_00 said, ''まあそんなこと言うと''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 353.03909375 - 353.62971875: SPEAKER_02 said, ''ノロッ''
# Turn's duration is under 2 sec. Unable to evaluate
# 355.67159375 - 356.07659375000003: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 357.24096875000004 - 359.51909375: SPEAKER_01 said, ''フォルム!は?もしかして?はぁ!''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 357.34221875000003 - 357.47721875: SPEAKER_00 said, ''フォッ''
# Turn's duration is under 2 sec. Unable to evaluate
# 360.56534375 - 364.96971875: SPEAKER_01 said, ''ナンバーがナンバーが前顔だ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 364.96971875 - 368.64846875: SPEAKER_02 said, ''これはやったー!オブライザー!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 369.22221875 - 377.87909375: SPEAKER_01 said, ''よかったなぁ!やったぁ!やっぱ人気店やったんや人気やから今回こっちに来たんやわだってもう、EAT INスペースあるもんなぁ!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 373.37346875 - 375.6347187500001: SPEAKER_00 said, ''やっと出会えた''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 375.6347187500001 - 375.76971875: SPEAKER_02 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 378.80721875 - 386.58659375: SPEAKER_01 said, ''ちゃんと何番あるかイベントに合わせてこっちに行きたいんやきっと出張できるんやケチャップソースがいいんだよ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 379.21221875 - 380.29221875: SPEAKER_00 said, ''イベントに合わせて''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 381.60846875 - 382.94159375: SPEAKER_00 said, ''ね、前から何かいいんだ''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 382.46909375 - 383.32971875: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 386.46846875 - 387.93659375: SPEAKER_00 said, ''とりあえず一通り撮ってみた''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 388.91534375 - 392.79659375: SPEAKER_00 said, ''ひもさんのひと通り好きやからな俺よしよしよしよし''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 395.4290937500001 - 395.47971875: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 399.95159375 - 400.18784375: SPEAKER_02 said, ''なの''
# Turn's duration is under 2 sec. Unable to evaluate
# 400.18784375 - 412.97909375: SPEAKER_01 said, ''上が宿泊施設かな施設?宿泊施設かなうわーいいお部屋宿泊施設かなやめろいいやん''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [2 3 7]
# Most Dominant: 戌亥とこ
# 403.00596875 - 403.96784375: SPEAKER_00 said, ''ししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししししし''
# Turn's duration is under 2 sec. Unable to evaluate
# 403.66409375 - 405.25034375: SPEAKER_02 said, ''シシッチュかなぁ''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 409.18221875 - 410.05971875: SPEAKER_02 said, ''やめな!''
# Turn's duration is under 2 sec. Unable to evaluate
# 417.53534375 - 417.55221875: SPEAKER_02 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 417.55221875 - 418.53096875: SPEAKER_01 said, ''殴れるようになった''
# Turn's duration is under 2 sec. Unable to evaluate
# 418.53096875 - 425.56784375: SPEAKER_02 said, ''知らないよあとで畜生好きだめーかだって!なぁ!やめろ!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 428.03159375 - 436.03034375: SPEAKER_02 said, ''あははははははは逆切れやばあはははははははすごいベクトルで消えてくる''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 436.03034375 - 439.05096875: SPEAKER_00 said, ''www化粧水とかじゃん、鏡''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 439.05096875 - 443.1684687500001: SPEAKER_01 said, ''あーダネこれねねーそうか、兄弟かへーすごーいで、フスマだこれ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 440.62034375 - 441.21096875: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 446.32409375 - 450.47534375: SPEAKER_00 said, ''まぁそう全部巡るのは多分無理とは思う''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 450.47534375 - 453.27659375: SPEAKER_01 said, ''でも、魚市場かここは''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 453.88409375 - 454.57596875: SPEAKER_01 said, ''おー!''
# Turn's duration is under 2 sec. Unable to evaluate
# 456.97221875 - 457.69784375: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 458.47409375 - 460.56659375: SPEAKER_01 said, ''魚だけにウォーってね''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 462.05159375000005 - 462.28784375: SPEAKER_01 said, ''by H.''
# Turn's duration is under 2 sec. Unable to evaluate
# 469.05471875 - 469.7465937500001: SPEAKER_02 said, ''いいね!''
# Turn's duration is under 2 sec. Unable to evaluate
# 471.46784375 - 478.69034375: SPEAKER_02 said, ''顔、そんなん入れ!うるせー!あんただよ、本当に!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 478.58909375 - 483.02721875: SPEAKER_00 said, ''- ハァッ! ハァッ!とか言われるより辛いタイプのw- 苦いw''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 481.03596875000005 - 486.72284375: SPEAKER_01 said, ''2022年脱つのによ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 483.02721875 - 483.2128437500001: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 486.72284375 - 487.97159375: SPEAKER_02 said, ''えwwww''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 487.97159375 - 496.35846875: SPEAKER_00 said, ''やっぱりとぼちゃんが反抗機になっちゃったペペペペちっちゃうのと怒っちゃったプンプンめっちゃそこの犬''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 498.80534375 - 499.02471875: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 499.02471875 - 502.53471875: SPEAKER_01 said, ''遠近法令でかくめるだけじゃない?誰かおる!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 502.53471875 - 503.29409375000006: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 503.93534375 - 506.01096875: SPEAKER_00 said, ''誰かもいる!本当だ!''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 506.66909375000006 - 512.11971875: SPEAKER_00 said, ''こんにちはあっあっ歌詞終わったんじゃないかミリアさんたちおれこっちおれこっちお疲れ様です''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 510.22971875 - 511.66409375: SPEAKER_01 said, ''おーおーおー''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 514.1784687500001 - 519.8315937500001: SPEAKER_00 said, ''今日出走だったんじゃないかあれあれあれお疲れ様ですこれいただくお疲れ様ですどうもどうも汚染多分''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 515.7309687500001 - 515.78159375: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 515.78159375 - 516.9797187500001: SPEAKER_02 said, ''お疲れ様でしたよこれ''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 516.9797187500001 - 517.23284375: SPEAKER_01 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 518.9878437500001 - 522.4809687500001: SPEAKER_02 said, ''大千玉子いっぱい作ったやな大千玉子可愛い''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 521.5359687499999 - 525.7378437500001: SPEAKER_00 said, ''お疲れ様です''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 522.4809687500001 - 522.5147187499999: SPEAKER_01 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 525.0290937500001 - 528.6909687500001: SPEAKER_01 said, ''カラフルで可愛いな可愛いねね、可愛い''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 526.48034375 - 527.0034687500001: SPEAKER_00 said, ''すごいね''
# Turn's duration is under 2 sec. Unable to evaluate
# 528.6909687500001 - 533.2978437500001: SPEAKER_00 said, ''確かさっき出走だった気がするから 戻られたんだね終わったんだな お疲れ様です''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 531.5090937500001 - 533.41596875: SPEAKER_01 said, ''終わったんだな お疲れ様です''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 534.6140937499999 - 535.89659375: SPEAKER_01 said, ''いいですね''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 536.48721875 - 542.4778437500001: SPEAKER_01 said, ''この顔文字っぽいやつ これどうやって手に入れるんだっけ?なんか言ってたよな顔文字ぽいやつあースタンプ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 541.0434687500001 - 548.18159375: SPEAKER_00 said, ''スタンプっぽいやからエモートっぽいのなんかポイント交換みたいな言ってなかったけどなんかそんなんやったよな''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 547.47284375 - 550.13909375: SPEAKER_01 said, ''ちょっと待って、私ら''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 550.7297187500001 - 556.46721875: SPEAKER_01 said, ''バカっぽすぎん?wwwwwwwwwwwそんなことないそんなことない全然そんなことない''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 556.46721875 - 558.98159375: SPEAKER_00 said, ''全然全然''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 557.5303437499999 - 558.15471875: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 558.98159375 - 559.52159375: SPEAKER_01 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 560.7365937500001 - 567.03096875: SPEAKER_01 said, ''じゃあ、まあ、行くよ。友達から見られてる気がする。これで温泉回ってる人みたいじゃない?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 562.0359687499999 - 565.03971875: SPEAKER_00 said, ''なんか友から見られてる気がするこれで温泉?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 567.03096875 - 571.0303437499999: SPEAKER_02 said, '' Emara&Oriすごいも Domene backside''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 571.0303437499999 - 571.1653437500001: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 571.9753437500001 - 574.75971875: SPEAKER_00 said, ''主脳を蹴るしてもスネーク えーと''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 576.9197187500001 - 584.5303437499999: SPEAKER_01 said, ''え?上がれないのかあれは飛べる人だけのあ、なるほどね風産権限権限なのあれなんかここ飛び降りそうなのがあるいや、死ぬぞ!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 585.7959687499999 - 586.4709687500001: SPEAKER_02 said, ''わかんなかった?今''
# Turn's duration is under 2 sec. Unable to evaluate
# 586.0322187500001 - 587.0615937499999: SPEAKER_00 said, ''ぺけたん いや、んー、きよっ''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 587.0615937499999 - 595.97159375: SPEAKER_02 said, ''ヒュンって今、ホントの辺りを狙ったヒュンが聞こえたけど気のせい気のせい死ぬぞって言った上で叩くのはもう殺すって意味なんだよねいやいや、アイス食べようと''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 589.66034375 - 591.29721875: SPEAKER_00 said, ''気のせい気のせい''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 594.4865937500001 - 598.75596875: SPEAKER_00 said, ''いやいや、アイス食べようとしただけ、アイス食べようと。ああ、本当に?シュー!パカーン!みたいな。''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 598.75596875 - 607.48034375: SPEAKER_02 said, ''あ〜そういうことだよ死を意識した途端にね生存法の方でお腹が空いたいなそうそう食欲が沸いてポクッってやったんだけどならしゃーないわ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 5]
# Most Dominant: 戌亥とこ
# 601.9284687500001 - 606.0290937500001: SPEAKER_00 said, ''そうそう食欲が沸いて僕ーってやったのに''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 606.0290937500001 - 610.58534375: SPEAKER_01 said, ''な、なんしゃらないわね、全然そうじゃんごめんごめんなんか、言いがかりみたいになっちゃってごめんごめん''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 608.1047187500001 - 608.59409375: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 609.9778437500001 - 616.52534375: SPEAKER_00 said, ''いいよいいよ、明日も気まどめし一緒に行くし、仲良くしといてもならねワイユー引きで''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 616.52534375 - 620.3897187499999: SPEAKER_02 said, ''そうかなあれ?あそこのうわ!なに?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 621.99284375 - 622.0265937500001: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 623.07284375 - 624.1359687500001: SPEAKER_00 said, ''みんなで聞こえなかったの?''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 628.6584687500001 - 632.5903437500001: SPEAKER_01 said, ''ドカーンって音聞こえなかった?えっ?聞こえないけど本当にドカーン?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 633.4340937500001 - 638.1928437500001: SPEAKER_01 said, ''なにドカンって?え、視聴者さんみんな聞こえたよね?え、聞こえたよね?ドコン!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 639.12096875 - 640.97721875: SPEAKER_01 said, ''あーほらほらほらほらほら!''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 640.97721875 - 642.96846875: SPEAKER_02 said, ''なになに怖いのどうしたの''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 641.07846875 - 664.46721875: SPEAKER_00 said, ''なになに怖いなぁどうしたの嘘嘘嘘おかしいおかしいいやいやいやどこに行こうしホントにもうホントになぁくんさんなったやんなぁホントだもん世界になってもんホントだもんホントだもんなんでちょっとまさおくみたいになるのホントだよ''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'アンジュ・カトリーナ' 'アンジュ・カトリーナ'
#  'アンジュ・カトリーナ' 'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [ 4  8 11]
# Most Dominant: 戌亥とこ
# 644.03159375 - 647.18721875: SPEAKER_02 said, ''アッキーちょっと悪ふざけしたからっていやいやいや''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 644.5378437500001 - 645.02721875: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 647.18721875 - 648.5203437499999: SPEAKER_01 said, ''どこに行こうしよう''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 664.46721875 - 676.00971875: SPEAKER_02 said, ''やめろ!ひどいよ!嘘つきおにぎりちょっと言わんやろぼーちゃん嘘つき嘘つき''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 7]
# Most Dominant: 戌亥とこ
# 676.97159375 - 678.4734687499999: SPEAKER_02 said, ''nan''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 680.21159375 - 680.86971875: SPEAKER_02 said, ''おらえないといけない''
# Turn's duration is under 2 sec. Unable to evaluate
# 680.2790937500001 - 682.97909375: SPEAKER_00 said, ''あ、今落としたの私は…''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 681.5278437500001 - 682.01721875: SPEAKER_02 said, ''私は''
# Turn's duration is under 2 sec. Unable to evaluate
# 683.82284375 - 684.41346875: SPEAKER_00 said, ''どこじゃん''
# Turn's duration is under 2 sec. Unable to evaluate
# 685.13909375 - 687.77159375: SPEAKER_00 said, ''あ、あ、終わった終わった、あ、取れた''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 690.1003437500001 - 691.73721875: SPEAKER_00 said, ''こう?見えてる?''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 693.0872187500001 - 696.66471875: SPEAKER_01 said, ''こうか?見える見える泣いてるどうした犬い!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 697.6772187500001 - 698.03159375: SPEAKER_02 said, ''ぜひ、ひとつまんで 안에を немножко observeしaliesじゃないでしょうかまああーなんか っていう感じの感じでしょうかちょっと求 reallyあの Eltern's Dayって感じでそうaltroになって帰ってるんですよね愛してる人とか pledgerが''
# Turn's duration is under 2 sec. Unable to evaluate
# 699.3647187500001 - 708.61221875: SPEAKER_02 said, ''wwwwwwwwwwwwもう一回失敗して''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 6]
# Most Dominant: 戌亥とこ
# 701.5247187500001 - 704.52846875: SPEAKER_00 said, ''wwwwwwwwww''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 709.7934687500001 - 709.97909375: SPEAKER_01 said, ''ん''
# Turn's duration is under 2 sec. Unable to evaluate
# 710.68784375 - 714.51846875: SPEAKER_01 said, ''もう一回心配してもっかいあんどいたいにー''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 717.03284375 - 722.0447187500001: SPEAKER_02 said, ''よかった!よかった!全然大丈夫みたい!よかった!やばいでしょ!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 719.3953437499999 - 719.9015937500001: SPEAKER_00 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 722.0447187500001 - 728.98034375: SPEAKER_00 said, ''よかったよ!もう一回心配してめっちゃ地以下のももんが''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 3]
# Most Dominant: 戌亥とこ
# 728.4740937500001 - 731.4272187500001: SPEAKER_02 said, ''あ、ぽいぽいぽいぽい''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 731.4272187500001 - 735.19034375: SPEAKER_01 said, ''おい心配しろちょっと履修してへんでんな''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 737.14784375 - 738.9028437500001: SPEAKER_01 said, ''ここは来た!''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 739.4428437500001 - 743.1047187500001: SPEAKER_00 said, ''ここは入ったとこやん黄色い建物って入ってきたとこだえ、あの''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 743.74596875 - 744.5222187500001: SPEAKER_00 said, ''顔メアリー''
# Turn's duration is under 2 sec. Unable to evaluate
# 744.03284375 - 746.69909375: SPEAKER_01 said, ''ごめん、あるよ。あ、はい。どうぞ。あ、どうぞ。え?''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 748.09971875 - 749.50034375: SPEAKER_01 said, ''撮ってあげるから2人用''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 750.63096875 - 752.7234687499999: SPEAKER_01 said, ''どうぞ''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 752.7234687499999 - 752.74034375: SPEAKER_00 said, ''ご視聴ありがとうございました''
# Turn's duration is under 2 sec. Unable to evaluate
# 753.5165937500001 - 755.0522187500001: SPEAKER_00 said, ''あーうちがやったらやるかな''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 754.71471875 - 754.90034375: SPEAKER_01 said, ''な''
# Turn's duration is under 2 sec. Unable to evaluate
# 756.41909375 - 760.46909375: SPEAKER_00 said, ''すごいなんかキラキラしてるなこの付近ねなんかすごいなこれうちの''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 758.37659375 - 761.1440937500001: SPEAKER_01 said, ''ねーなんかすごいよねこれうちの輝きじゃない?''
# ['リゼ・ヘルエスタ' '戌亥とこ']
# ['リゼ・ヘルエスタ' '戌亥とこ']
# [1 1]
# Most Dominant: リゼ・ヘルエスタ
# 760.46909375 - 760.9753437500001: SPEAKER_02 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 762.5109687500001 - 764.46846875: SPEAKER_01 said, ''あ、誰かおるあ、うまい私''
# ['戌亥とこ']
# ['戌亥とこ']
# [1]
# Most Dominant: 戌亥とこ
# 764.02971875 - 764.55284375: SPEAKER_00 said, ''はい、私''
# Turn's duration is under 2 sec. Unable to evaluate
# 765.6497187500001 - 769.24409375: SPEAKER_00 said, ''ほんとだ、あっいるのうまい!''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 1]
# Most Dominant: アンジュ・カトリーナ
# 767.37096875 - 767.92784375: SPEAKER_01 said, ''うまい!''
# Turn's duration is under 2 sec. Unable to evaluate
# 770.79659375 - 775.5890937500001: SPEAKER_01 said, ''おいで片方開いてるよ肩が若干出てるあっ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 1 2]
# Most Dominant: 戌亥とこ
# 771.18471875 - 771.4209687500002: SPEAKER_00 said, ''おいでっ''
# Turn's duration is under 2 sec. Unable to evaluate
# 776.97284375 - 777.0234687500001: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 777.0234687500001 - 777.2934687500001: SPEAKER_02 said, ''はっはっは''
# Turn's duration is under 2 sec. Unable to evaluate
# 777.93471875 - 787.8740937500002: SPEAKER_02 said, ''あーーーあーーーあーーーしのーけんしのーけんしのーけん立って!立って!はい、撮った撮った''
# ['アンジュ・カトリーナ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ'
#  'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 6]
# Most Dominant: 戌亥とこ
# 781.05659375 - 781.47846875: SPEAKER_01 said, ''nan''
# Turn's duration is under 2 sec. Unable to evaluate
# 787.8740937500002 - 788.59971875: SPEAKER_01 said, ''ありがとう''
# Turn's duration is under 2 sec. Unable to evaluate
# 789.8315937500001 - 797.08784375: SPEAKER_01 said, ''死ぬだけでいいんか?顔が出てるところで噛むへん噛むあれ?ここ行ってないんじゃない?''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 3 3]
# Most Dominant: リゼ・ヘルエスタ
# 798.31971875 - 803.4328437500001: SPEAKER_01 said, ''ここがあのでかいやつだな多分あ、本当だ!ここ行ってないこれだこれだ''
# ['アンジュ・カトリーナ' '戌亥とこ' 'リゼ・ヘルエスタ' '戌亥とこ' 'リゼ・ヘルエスタ']
# ['アンジュ・カトリーナ' 'リゼ・ヘルエスタ' '戌亥とこ']
# [1 2 2]
# Most Dominant: リゼ・ヘルエスタ
# 800.00721875 - 800.02409375: SPEAKER_02 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 800.73284375 - 800.96909375: SPEAKER_02 said, ''ご視聴ありがとうございました!''
# Turn's duration is under 2 sec. Unable to evaluate
# 802.4540937500001 - 802.97721875: SPEAKER_02 said, ''これだこれだ''
# Turn's duration is under 2 sec. Unable to evaluate

# %%
def format_time(secs: float) -> str:
    """Convert seconds as float to SRT time format (hh:mm:ss,ms)."""
    hours =  int(secs) // 3600
    minutes = (int(secs) % 3600) // 60
    seconds = ( int(secs) % 60 ) // 1
    milliseconds = int((secs - (int(secs) // 1)) * 1000 )
    return f"{str(hours).zfill(2)}:{str(minutes).zfill(2)}:{str(seconds).zfill(2)},{str(milliseconds).zfill(3)}"

def create_srt_entry(index: int, start_time: float, end_time: float, text: str, color_code: str) -> str:
    """Create a formatted SRT entry."""
    start_time_str = format_time(start_time)
    end_time_str = format_time(end_time)
    formatted_text = f"[color={color_code}]{text}[/color]"
    return f"{index}\n{start_time_str} --> {end_time_str}\n{formatted_text}\n"

def write_srt_file(entries: list, output_file: str):
    """Write entries to an SRT file."""
    with open(output_file, 'w', encoding='utf-8') as file:
        for i, entry in enumerate(entries, start=1):
            file.write(create_srt_entry(i, entry['start'], entry['end'], entry['text'], entry['color']))
            file.write("\n")

# Write to an SRT file
write_srt_file(srt_elements, '../srt-on-video/public/sanbaka-sightseeing.srt')
